# %%
#使用2維的list
#50個學生,每個學生的分數
import random
students = []
for j in range (50):
    scores = []
    for i in range (5):
        scores.append(random.randint(50,100))
    students.append(scores)
students
# Out:
# [[65, 99, 57, 90, 70],
#  [100, 62, 93, 61, 96],
#  [94, 94, 97, 70, 79],
#  [88, 74, 67, 96, 89],
#  [58, 91, 81, 53, 59],
#  [77, 64, 91, 67, 92],
#  [62, 99, 77, 69, 84],
#  [72, 86, 82, 71, 73],
#  [74, 59, 80, 79, 85],
#  [71, 96, 99, 62, 93],
#  [91, 56, 76, 69, 64],
#  [58, 99, 52, 79, 55],
#  [82, 75, 63, 56, 70],
#  [62, 55, 93, 88, 80],
#  [94, 95, 62, 62, 61],
#  [80, 76, 67, 65, 53],
#  [65, 85, 99, 73, 50],
#  [58, 84, 85, 81, 59],
#  [91, 90, 62, 57, 84],
#  [81, 56, 78, 92, 70],
#  [71, 69, 64, 69, 92],
#  [96, 85, 82, 59, 77],
#  [56, 83, 69, 91, 100],
#  [55, 93, 83, 80, 71],
#  [50, 76, 54, 54, 86],
#  [56, 71, 73, 52, 61],
#  [97, 71, 72, 91, 76],
#  [59, 61, 54, 58, 96],
#  [70, 65, 64, 65, 79],
#  [71, 70, 88, 70, 94],
#  [92, 70, 69, 92, 51],
#  [73, 92, 77, 92, 65],
#  [98, 94, 99, 80, 75],
#  [61, 100, 100, 60, 73],
#  [84, 92, 94, 91, 58],
#  [88, 89, 59, 88, 100],
#  [64, 97, 78, 79, 91],
#  [97, 94, 60, 60, 93],
#  [51, 96, 78, 53, 80],
# ...
